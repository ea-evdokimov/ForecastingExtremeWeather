# %%
import pandas as pd

# %%
import typing as tp
import numpy as np
from collections import defaultdict
from pydantic import BaseModel


class WindDescription(BaseModel):
    isnan: bool
    changed: bool
    x_rad: float
    y_rad: float


def dd_preparation(description: tp.Optional[str]) -> WindDescription:
    '''
    :param description: string description of wind
    :return: WindDescription object
    '''
    if description is None or not isinstance(description, str):
        return WindDescription(isnan=True, changed=False, x_rad=0., y_rad=0.)
    
    prepared_description = description.lower()

    if 'переменное направление'.lower() in prepared_description:
        return WindDescription(isnan=False, changed=True, x_rad=0., y_rad=0.)

    if 'штиль' in prepared_description or 'безветрие' in prepared_description:
        return WindDescription(isnan=False, changed=False, x_rad=0., y_rad=0.)

    dest_to_rad = {'восток': 0,
                   'север': np.pi / 2,
                   'запад': np.pi,
                   'юг': 3 * np.pi / 2}
    
    counts = {k: prepared_description.count(k) for k in dest_to_rad if prepared_description.count(k) > 0}
    
    count = sum((v for v in counts.values()))
    angle = sum((c * dest_to_rad[dest] for dest, c in counts.items()))
    
    if 'восток' in counts and 'юг' in counts:
        angle += counts['восток'] * 2 * np.pi
    
    res_angle = angle / count
    
    return WindDescription(isnan=False, changed=False, x_rad=np.cos(res_angle), y_rad=np.sin(res_angle)).dict()

# %%
pd.json_normalize(weather_data.DD.map(dd_preparation))
# Out:
#         isnan changed         x_rad         y_rad
# 0       False   False -5.000000e-01  8.660254e-01
# 1       False   False -7.071068e-01  7.071068e-01
# 2       False   False -7.071068e-01  7.071068e-01
# 3       False   False -7.071068e-01  7.071068e-01
# 4       False   False -1.836970e-16 -1.000000e+00
# ...       ...     ...           ...           ...
# 356501  False   False -1.000000e+00  1.224647e-16
# 356502  False   False -1.000000e+00  1.224647e-16
# 356503  False   False -8.660254e-01  5.000000e-01
# 356504  False   False -8.660254e-01  5.000000e-01
# 356505  False   False -8.660254e-01  5.000000e-01
#
# [356506 rows x 4 columns]

# %%
pd.DataFrame.from_records(weather_data.DD.map(dd_preparation))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [36], line 1
# ----> 1 pd.DataFrame.from_records(weather_data.DD.map(dd_preparation))
#
# File ~/anaconda3/envs/alice/lib/python3.8/site-packages/pandas/core/frame.py:2336, in DataFrame.from_records(cls, data, index, exclude, columns, coerce_float, nrows)
#    2334     arr_columns = columns
#    2335 else:
# -> 2336     arrays, arr_columns = to_arrays(data, columns)
#    2337     if coerce_float:
#    2338         for i, arr in enumerate(arrays):
#
# File ~/anaconda3/envs/alice/lib/python3.8/site-packages/pandas/core/internals/construction.py:867, in to_arrays(data, columns, dtype)
#     865     arr = _list_to_arrays(data)
#     866 elif isinstance(data[0], abc.Mapping):
# --> 867     arr, columns = _list_of_dict_to_arrays(data, columns)
#     868 elif isinstance(data[0], ABCSeries):
#     869     arr, columns = _list_of_series_to_arrays(data, columns)
#
# File ~/anaconda3/envs/alice/lib/python3.8/site-packages/pandas/core/internals/construction.py:947, in _list_of_dict_to_arrays(data, columns)
#     945     gen = (list(x.keys()) for x in data)
#     946     sort = not any(isinstance(d, dict) for d in data)
# --> 947     pre_cols = lib.fast_unique_multiple_list_gen(gen, sort=sort)
#     948     columns = ensure_index(pre_cols)
#     950 # assure that they are of the base dict class and not of derived
#     951 # classes
#
# File ~/anaconda3/envs/alice/lib/python3.8/site-packages/pandas/_libs/lib.pyx:416, in pandas._libs.lib.fast_unique_multiple_list_gen()
#
# File ~/anaconda3/envs/alice/lib/python3.8/site-packages/pandas/core/internals/construction.py:945, in <genexpr>(.0)
#     925 """
#     926 Convert list of dicts to numpy arrays
#     927
#    (...)
#     942 columns : Index
#     943 """
#     944 if columns is None:
# --> 945     gen = (list(x.keys()) for x in data)
#     946     sort = not any(isinstance(d, dict) for d in data)
#     947     pre_cols = lib.fast_unique_multiple_list_gen(gen, sort=sort)
#
# AttributeError: 'WindDescription' object has no attribute 'keys'

# %%
weather_data = pd.read_csv('../data/weather_train.csv', sep=';')
weather_data.head()
# Out:
# /tmp/ipykernel_34740/912182901.py:1: DtypeWarning: Columns (22) have mixed types. Specify dtype option on import or set low_memory=False.
#   weather_data = pd.read_csv('../data/weather_train.csv', sep=';')
#    Unnamed: 0        local_time    T     Po      P   Pa     U  \
# 0           0  31.12.2013 21:00 -1.5  758.9  773.2  0.7  99.0
# 1           1  31.12.2013 18:00 -1.7  758.2  772.5  0.7  99.0
# 2           2  31.12.2013 15:00 -1.7  757.5  771.8  0.0  99.0
# 3           3  31.12.2013 12:00 -1.2  757.5  771.7  0.8  99.0
# 4           4  31.12.2013 09:00 -1.2  756.7  770.9  1.2  99.0
#
#                                      DD   Ff  ff10  ...   Ch   VV   Td  \
# 0  Ветер, дующий с северо-северо-запада  2.0   NaN  ...  NaN  6.0 -1.6
# 1         Ветер, дующий с северо-запада  3.0   NaN  ...  NaN  3.0 -1.9
# 2         Ветер, дующий с северо-запада  4.0   NaN  ...  NaN  3.0 -1.9
# 3         Ветер, дующий с северо-запада  3.0   NaN  ...  NaN  2.5 -1.4
# 4                   Ветер, дующий с юга  3.0   NaN  ...  NaN  0.5 -1.4
#
#            RRR    tR    E  Tg   E'  sss station_id
# 0          NaN   NaN  NaN NaN  NaN  NaN      34123
# 1  Осадков нет  12.0  NaN NaN  NaN  NaN      34123
# 2          NaN   NaN  NaN NaN  NaN  NaN      34123
# 3          NaN   NaN  NaN NaN  NaN  NaN      34123
# 4          NaN   NaN  NaN NaN  NaN  NaN      34123
#
# [5 rows x 31 columns]
