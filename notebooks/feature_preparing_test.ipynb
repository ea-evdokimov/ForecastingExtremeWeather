# %%
import pandas as pd
import sys
import os
sys.path.append('/home/platinsky/Documents/hack/ForecastingExtremeWeather/lib/')
import feature_preparation as feat_prepare

# %%
weather_data = pd.read_csv('../data/weather_train.csv', sep=';')
weather_data.head()
# Out:
# /tmp/ipykernel_40125/912182901.py:1: DtypeWarning: Columns (22) have mixed types. Specify dtype option on import or set low_memory=False.
#   weather_data = pd.read_csv('../data/weather_train.csv', sep=';')
#    Unnamed: 0        local_time    T     Po      P   Pa     U  \
# 0           0  31.12.2013 21:00 -1.5  758.9  773.2  0.7  99.0
# 1           1  31.12.2013 18:00 -1.7  758.2  772.5  0.7  99.0
# 2           2  31.12.2013 15:00 -1.7  757.5  771.8  0.0  99.0
# 3           3  31.12.2013 12:00 -1.2  757.5  771.7  0.8  99.0
# 4           4  31.12.2013 09:00 -1.2  756.7  770.9  1.2  99.0
#
#                                      DD   Ff  ff10  ...   Ch   VV   Td  \
# 0  Ветер, дующий с северо-северо-запада  2.0   NaN  ...  NaN  6.0 -1.6
# 1         Ветер, дующий с северо-запада  3.0   NaN  ...  NaN  3.0 -1.9
# 2         Ветер, дующий с северо-запада  4.0   NaN  ...  NaN  3.0 -1.9
# 3         Ветер, дующий с северо-запада  3.0   NaN  ...  NaN  2.5 -1.4
# ...

# %%
ext_weather = pd.merge(weather_data, pd.json_normalize(weather_data.DD.map(feat_prepare.dd_preparation)), left_index=True, right_index=True)

# %%
ext_weather.groupby(['DD'], dropna=False).first()
# Out:
#                                         Unnamed: 0        local_time     T  \
# DD
# Ветер, дующий с востока                        343  19.11.2013 00:00  -1.1
# Ветер, дующий с востоко-северо-востока         387  13.11.2013 12:00   6.9
# Ветер, дующий с востоко-юго-востока             39  27.12.2013 00:00  -2.8
# Ветер, дующий с запада                           6  31.12.2013 03:00  -1.4
# Ветер, дующий с западо-северо-запада             7  31.12.2013 00:00  -1.5
# Ветер, дующий с западо-юго-запада                9  30.12.2013 18:00  -0.6
# Ветер, дующий с севера                         160  11.12.2013 21:00 -15.1
# Ветер, дующий с северо-востока                 383  14.11.2013 00:00   6.7
# Ветер, дующий с северо-запада                    1  31.12.2013 18:00  -1.7
# Ветер, дующий с северо-северо-востока          173  10.12.2013 06:00  -7.6
# Ветер, дующий с северо-северо-запада             0  31.12.2013 21:00  -1.5
# ...
